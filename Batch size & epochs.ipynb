# %%
# Use scikit-learn to grid search the batch size and epochs
#import numpy
import numpy as np
import pandas as pd
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
# Function to create model, required for KerasClassifier
def create_model():
	# create model
	model = Sequential()
	model.add(Dense(80,  activation='relu'))
	model.add(Dense(50, activation='relu'))
	model.add(Dense(50, activation='relu'))
	model.add(Dense(20, activation='relu'))
	model.add(Dense(10, activation='relu'))
	model.add(Dense(1, activation='relu'))
	# Compile model
	model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
	return model
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load dataset
dataset = numpy.loadtxt("/Users/markjuvert/Desktop/RNN/Limestone_data.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,2]
# create model
model = KerasClassifier(build_fn=create_model, verbose=0)
# define the grid search parameters
batch_size = [8, 10, 20,32, 40, 60, 70, 80, 100]
epochs = [10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100]
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.101587 using {'batch_size': 40, 'epochs': 15}
# 0.090159 (0.119422) with: {'batch_size': 8, 'epochs': 10}
# 0.000635 (0.000898) with: {'batch_size': 8, 'epochs': 15}
# 0.093968 (0.116822) with: {'batch_size': 8, 'epochs': 20}
# 0.097143 (0.116092) with: {'batch_size': 8, 'epochs': 30}
# 0.089524 (0.119934) with: {'batch_size': 8, 'epochs': 40}
# 0.090159 (0.119514) with: {'batch_size': 8, 'epochs': 50}
# 0.088254 (0.115510) with: {'batch_size': 8, 'epochs': 60}
# 0.094603 (0.116407) with: {'batch_size': 8, 'epochs': 70}
# 0.086349 (0.118099) with: {'batch_size': 8, 'epochs': 80}
# 0.090794 (0.124383) with: {'batch_size': 8, 'epochs': 90}
# 0.092698 (0.124422) with: {'batch_size': 8, 'epochs': 100}
# 0.086349 (0.122116) with: {'batch_size': 10, 'epochs': 10}
# 0.003175 (0.002376) with: {'batch_size': 10, 'epochs': 15}
# 0.042540 (0.048195) with: {'batch_size': 10, 'epochs': 20}
# 0.090159 (0.118140) with: {'batch_size': 10, 'epochs': 30}
# 0.090159 (0.119422) with: {'batch_size': 10, 'epochs': 40}
# 0.022222 (0.020885) with: {'batch_size': 10, 'epochs': 50}
# 0.095238 (0.115841) with: {'batch_size': 10, 'epochs': 60}
# 0.006349 (0.006475) with: {'batch_size': 10, 'epochs': 70}
# 0.005079 (0.003914) with: {'batch_size': 10, 'epochs': 80}
# 0.093968 (0.119675) with: {'batch_size': 10, 'epochs': 90}
# 0.094603 (0.123171) with: {'batch_size': 10, 'epochs': 100}
# 0.001905 (0.002694) with: {'batch_size': 20, 'epochs': 10}
# 0.086349 (0.122116) with: {'batch_size': 20, 'epochs': 15}
# 0.090794 (0.119037) with: {'batch_size': 20, 'epochs': 20}
# 0.088889 (0.120361) with: {'batch_size': 20, 'epochs': 30}
# 0.088889 (0.125708) with: {'batch_size': 20, 'epochs': 40}
# 0.092698 (0.117883) with: {'batch_size': 20, 'epochs': 50}
# 0.095873 (0.115970) with: {'batch_size': 20, 'epochs': 60}
# 0.092063 (0.118099) with: {'batch_size': 20, 'epochs': 70}
# 0.085079 (0.120320) with: {'batch_size': 20, 'epochs': 80}
# 0.091429 (0.125281) with: {'batch_size': 20, 'epochs': 90}
# 0.012698 (0.011464) with: {'batch_size': 20, 'epochs': 100}
# 0.093333 (0.117489) with: {'batch_size': 32, 'epochs': 10}
# 0.071111 (0.095230) with: {'batch_size': 32, 'epochs': 15}
# 0.040000 (0.052580) with: {'batch_size': 32, 'epochs': 20}
# 0.089524 (0.119894) with: {'batch_size': 32, 'epochs': 30}
# 0.087619 (0.121228) with: {'batch_size': 32, 'epochs': 40}
# 0.091429 (0.121308) with: {'batch_size': 32, 'epochs': 50}
# 0.010794 (0.009877) with: {'batch_size': 32, 'epochs': 60}
# 0.092698 (0.124422) with: {'batch_size': 32, 'epochs': 70}
# 0.092063 (0.113141) with: {'batch_size': 32, 'epochs': 80}
# 0.090159 (0.119463) with: {'batch_size': 32, 'epochs': 90}
# 0.036190 (0.028803) with: {'batch_size': 32, 'epochs': 100}
# 0.092698 (0.117791) with: {'batch_size': 40, 'epochs': 10}
# 0.101587 (0.111385) with: {'batch_size': 40, 'epochs': 15}
# 0.003175 (0.004490) with: {'batch_size': 40, 'epochs': 20}
# 0.092063 (0.116770) with: {'batch_size': 40, 'epochs': 30}
# 0.088254 (0.120792) with: {'batch_size': 40, 'epochs': 40}
# 0.084444 (0.119422) with: {'batch_size': 40, 'epochs': 50}
# 0.099048 (0.125377) with: {'batch_size': 40, 'epochs': 60}
# 0.088889 (0.121690) with: {'batch_size': 40, 'epochs': 70}
# 0.092698 (0.117668) with: {'batch_size': 40, 'epochs': 80}
# 0.093333 (0.117489) with: {'batch_size': 40, 'epochs': 90}
# 0.089524 (0.119934) with: {'batch_size': 40, 'epochs': 100}
# 0.086349 (0.122116) with: {'batch_size': 60, 'epochs': 10}
# 0.001270 (0.000898) with: {'batch_size': 60, 'epochs': 15}
# 0.090159 (0.119463) with: {'batch_size': 60, 'epochs': 20}
# 0.055873 (0.072387) with: {'batch_size': 60, 'epochs': 30}
# 0.090794 (0.119098) with: {'batch_size': 60, 'epochs': 40}
# 0.086984 (0.121670) with: {'batch_size': 60, 'epochs': 50}
# 0.090159 (0.119433) with: {'batch_size': 60, 'epochs': 60}
# 0.089524 (0.119934) with: {'batch_size': 60, 'epochs': 70}
# 0.087619 (0.118535) with: {'batch_size': 60, 'epochs': 80}
# 0.008254 (0.004751) with: {'batch_size': 60, 'epochs': 90}
# 0.085714 (0.121218) with: {'batch_size': 60, 'epochs': 100}
# 0.002540 (0.002376) with: {'batch_size': 70, 'epochs': 10}
# 0.000635 (0.000898) with: {'batch_size': 70, 'epochs': 15}
# 0.006349 (0.004751) with: {'batch_size': 70, 'epochs': 20}
# 0.091429 (0.118688) with: {'batch_size': 70, 'epochs': 30}
# 0.000635 (0.000898) with: {'batch_size': 70, 'epochs': 40}
# 0.092698 (0.120481) with: {'batch_size': 70, 'epochs': 50}
# 0.086349 (0.122116) with: {'batch_size': 70, 'epochs': 60}
# 0.019048 (0.003110) with: {'batch_size': 70, 'epochs': 70}
# 0.099683 (0.113012) with: {'batch_size': 70, 'epochs': 80}
# 0.097778 (0.115594) with: {'batch_size': 70, 'epochs': 90}
# 0.088889 (0.116345) with: {'batch_size': 70, 'epochs': 100}
# 0.000000 (0.000000) with: {'batch_size': 80, 'epochs': 10}
# 0.001270 (0.001796) with: {'batch_size': 80, 'epochs': 15}
# 0.003810 (0.002694) with: {'batch_size': 80, 'epochs': 20}
# 0.041905 (0.040406) with: {'batch_size': 80, 'epochs': 30}
# 0.076190 (0.099778) with: {'batch_size': 80, 'epochs': 40}
# 0.085714 (0.117201) with: {'batch_size': 80, 'epochs': 50}
# 0.086984 (0.123014) with: {'batch_size': 80, 'epochs': 60}
# 0.011429 (0.002694) with: {'batch_size': 80, 'epochs': 70}
# 0.088254 (0.123466) with: {'batch_size': 80, 'epochs': 80}
# 0.089524 (0.119934) with: {'batch_size': 80, 'epochs': 90}
# 0.086349 (0.122116) with: {'batch_size': 80, 'epochs': 100}
# 0.000000 (0.000000) with: {'batch_size': 100, 'epochs': 10}
# 0.000000 (0.000000) with: {'batch_size': 100, 'epochs': 15}
# 0.000635 (0.000898) with: {'batch_size': 100, 'epochs': 20}
# 0.086984 (0.121670) with: {'batch_size': 100, 'epochs': 30}
# 0.093968 (0.116894) with: {'batch_size': 100, 'epochs': 40}
# 0.090159 (0.119514) with: {'batch_size': 100, 'epochs': 50}
# 0.093333 (0.117180) with: {'batch_size': 100, 'epochs': 60}
# 0.089524 (0.119874) with: {'batch_size': 100, 'epochs': 70}
# 0.086984 (0.123014) with: {'batch_size': 100, 'epochs': 80}
# 0.086349 (0.122116) with: {'batch_size': 100, 'epochs': 90}
# 0.086349 (0.119422) with: {'batch_size': 100, 'epochs': 100}
